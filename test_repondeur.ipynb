# %%
import torch
import torch.nn as nn
import torchinfo
from model.mini_cnn import MiniCNN
from result.repondeur import prediction_to_csv

# %%
import pandas as pd

df = pd.read_csv("./data/train.csv")
df['id'] = df['id'].str.split('/').str[1]
df = df.drop_duplicates().reset_index(drop=True)
df.rename({"id":"species", "label":"label"})
print(df)
df.to_csv("./data/treated_train.csv")
# Out:
#                         id  label
# 0      Andrena aerinifrons      3
# 1         Andrena afrensis     34
# 2          Andrena aliciae     14
# 3   Andrena angustitarsata      9
# 4           Andrena banksi     45
# 5        Andrena barbareae     42
# 6      Andrena barbilabris     43
# 7          Andrena bicolor      2
# 8      Andrena carantonica     36
# 9    Andrena chengtehensis      7
# 10       Andrena cineraria     40
# 11       Andrena clarkella     18
# 12     Andrena convallaria     11
# 13    Andrena costillensis     10
# 14       Andrena crawfordi      8
# 15     Andrena denticulata     25
# 16         Andrena discors     29
# 17         Andrena dorsata     32
# 18        Andrena flavipes     12
# 19       Andrena florivaga     21
# 20   Andrena fortipunctata      1
# 21           Andrena fulva     49
# 22         Andrena fulvata     27
# 23      Andrena haemorrhoa      5
# 24     Andrena hattorfiana     19
# 25        Andrena hesperia     16
# 26           Andrena irana     20
# 27      Andrena leucophaea     46
# 28         Andrena limbata     39
# 29       Andrena lineolata     37
# 30    Andrena mediovittata     15
# 31     Andrena melanochroa     35
# 32         Andrena mendica     33
# 33      Andrena nigroaenea     28
# 34          Andrena nitida     24
# 35       Andrena orbitalis      6
# 36       Andrena perimelas     47
# 37        Andrena perplexa     44
# 38           Andrena plana     38
# 39      Andrena rudbeckiae     23
# 40          Andrena rufula     31
# 41            Andrena vaga     22
# 42       Andrena ventralis     17
# 43      Andrena vicinoides     30
# 44        Andrena villipes     13
# 45       Andrena vulpecula      4
# 46        Andrena wilkella     41

# %%
id_to_label = dict(zip(df['id'], df['label']))
id_to_label
# Out:
# {'Andrena aerinifrons': 3,
#  'Andrena afrensis': 34,
#  'Andrena aliciae': 14,
#  'Andrena angustitarsata': 9,
#  'Andrena banksi': 45,
#  'Andrena barbareae': 42,
#  'Andrena barbilabris': 43,
#  'Andrena bicolor': 2,
#  'Andrena carantonica': 36,
#  'Andrena chengtehensis': 7,
#  'Andrena cineraria': 40,
#  'Andrena clarkella': 18,
#  'Andrena convallaria': 11,
#  'Andrena costillensis': 10,
#  'Andrena crawfordi': 8,
#  'Andrena denticulata': 25,
#  'Andrena discors': 29,
#  'Andrena dorsata': 32,
#  'Andrena flavipes': 12,
#  'Andrena florivaga': 21,
#  'Andrena fortipunctata': 1,
#  'Andrena fulva': 49,
#  'Andrena fulvata': 27,
#  'Andrena haemorrhoa': 5,
#  'Andrena hattorfiana': 19,
#  'Andrena hesperia': 16,
#  'Andrena irana': 20,
#  'Andrena leucophaea': 46,
#  'Andrena limbata': 39,
#  'Andrena lineolata': 37,
#  'Andrena mediovittata': 15,
#  'Andrena melanochroa': 35,
#  'Andrena mendica': 33,
#  'Andrena nigroaenea': 28,
#  'Andrena nitida': 24,
#  'Andrena orbitalis': 6,
#  'Andrena perimelas': 47,
#  'Andrena perplexa': 44,
#  'Andrena plana': 38,
#  'Andrena rudbeckiae': 23,
#  'Andrena rufula': 31,
#  'Andrena vaga': 22,
#  'Andrena ventralis': 17,
#  'Andrena vicinoides': 30,
#  'Andrena villipes': 13,
#  'Andrena vulpecula': 4,
#  'Andrena wilkella': 41}

# %%
model = MiniCNN(num_classes=50) # model non-entraine

model.load_state_dict(torch.load("./model/trained_model/MiniCNN_5_epochs.pth"))

prediction_to_csv(
    dir="data/test",
    model=model,
    img_size=224,
    batch_size=16
)
# Out:
# ⚠ Using CPU - training will be slow!
# Inference:   0%|          | 0/125 [00:00<?, ?it/s]/home/niels/.sdd_venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Inference: 100%|██████████| 125/125 [00:22<00:00,  5.67it/s]
# Les predictions ont été sauvegardees dans prediction.csv.
