# %%
import torch
import torch.nn as nn
import torchinfo
from mini_cnn import MiniCNN

# %%
# Check for GPU availability
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"✓ Using GPU: {torch.cuda.get_device_name(0)}")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
    print("✓ Using Apple Silicon GPU (MPS)")
else:
    device = torch.device("cpu")
    print("⚠ Using CPU - training will be slow!")
# Out:
# ✓ Using Apple Silicon GPU (MPS)

# %%
student = MiniCNN()
student.to(device)
torchinfo.summary(student, input_size=(1, 3, 224, 224), device=device)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MiniCNN                                  [1, 50]                   --
# ├─ConvBlock: 1-1                         [1, 16, 224, 224]         --
# │    └─Conv2d: 2-1                       [1, 16, 224, 224]         448
# │    └─BatchNorm2d: 2-2                  [1, 16, 224, 224]         32
# │    └─ReLU: 2-3                         [1, 16, 224, 224]         --
# ├─MaxPool2d: 1-2                         [1, 16, 112, 112]         --
# ├─ConvBlock: 1-3                         [1, 32, 112, 112]         --
# │    └─Conv2d: 2-4                       [1, 32, 112, 112]         4,640
# │    └─BatchNorm2d: 2-5                  [1, 32, 112, 112]         64
# │    └─ReLU: 2-6                         [1, 32, 112, 112]         --
# ├─MaxPool2d: 1-4                         [1, 32, 56, 56]           --
# ├─ConvBlock: 1-5                         [1, 64, 56, 56]           --
# │    └─Conv2d: 2-7                       [1, 64, 56, 56]           18,496
# │    └─BatchNorm2d: 2-8                  [1, 64, 56, 56]           128
# │    └─ReLU: 2-9                         [1, 64, 56, 56]           --
# ├─MaxPool2d: 1-6                         [1, 64, 28, 28]           --
# ├─ConvBlock: 1-7                         [1, 128, 28, 28]          --
# │    └─Conv2d: 2-10                      [1, 128, 28, 28]          73,856
# │    └─BatchNorm2d: 2-11                 [1, 128, 28, 28]          256
# │    └─ReLU: 2-12                        [1, 128, 28, 28]          --
# ├─MaxPool2d: 1-8                         [1, 128, 14, 14]          --
# ├─ConvBlock: 1-9                         [1, 256, 14, 14]          --
# │    └─Conv2d: 2-13                      [1, 256, 14, 14]          295,168
# │    └─BatchNorm2d: 2-14                 [1, 256, 14, 14]          512
# │    └─ReLU: 2-15                        [1, 256, 14, 14]          --
# ├─MaxPool2d: 1-10                        [1, 256, 7, 7]            --
# ├─Sequential: 1-11                       [1, 50]                   --
# │    └─AdaptiveAvgPool2d: 2-16           [1, 256, 1, 1]            --
# │    └─Flatten: 2-17                     [1, 256]                  --
# │    └─Linear: 2-18                      [1, 50]                   12,850
# ==========================================================================================
# Total params: 406,450
# Trainable params: 406,450
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 254.46
# ==========================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 24.89
# Params size (MB): 1.63
# Estimated Total Size (MB): 27.12
# ==========================================================================================

# %%
pwd()
# Out:
# '/Users/thomas/SDD/hackaton/MielPops/model'

# %%
from loader import load_test_loader

load_test_loader("../data/test")
